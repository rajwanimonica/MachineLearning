# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('E://desktop/data/BostonHousing.csv')
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.isnull().any()
# Out:
# crim       False
# zn         False
# indus      False
# chas       False
# nox        False
# rm         False
# age        False
# dis        False
# rad        False
# tax        False
# ptratio    False
# b          False
# lstat      False
# medv       False
# dtype: bool

# %% [markdown]
# #so there is no null value  in dataframe

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
cor_matrix=df.corr().round(2)
plt.figure(figsize=(10,10))
sns.heatmap(data=cor_matrix,annot=True)
plt.show()

# %%
#medv is our target
#and medv is our target i.e MEDV: Median value of owner-occupied homes in $1000s
# By looking at the correlation matrix we can see that rm has a strong positive correlation with medv(0.7)
#lstat has a high negative correlation with medv(-0.74).
# The features rad, tax have a correlation of 0.91. These feature pairs are strongly correlated to each other. but rad is not corelated with medv.so we should not take them together or training model
#dis and age which have a correlation of -0.75.so we should not take them them together for training model
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.scatter(df['lstat'],df['medv'],marker='o',color='green')
plt.xlabel('lstat')
plt.ylabel('medv')
plt.subplot(1,2,2)
plt.scatter(df['rm'],df['medv'],marker='o',color='red')
plt.xlabel('rm')
plt.ylabel('medv')
plt.show()

# %%
#creating dataframe for for train and test
new_df=df[['rm','lstat','medv']]
new_df
# Out:
#         rm  lstat  medv
# 0    6.575   4.98  24.0
# 1    6.421   9.14  21.6
# 2    7.185   4.03  34.7
# 3    6.998   2.94  33.4
# 4    7.147   5.33  36.2
# ..     ...    ...   ...
# 501  6.593   9.67  22.4
# 502  6.120   9.08  20.6
# 503  6.976   5.64  23.9
# 504  6.794   6.48  22.0
# 505  6.030   7.88  11.9
#
# [506 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
xtrain,xtest,ytrain,ytest=tts(df[['rm','lstat']],df['medv'], test_size=0.30)
lr=LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.6209042509400474

# %% [markdown]
# #The model performance for training set is 0.667

# %%
yh=lr.predict(xtest)
yh
# Out:
# array([26.04852255, 19.35680692, 25.24268523, 32.11577027, 29.91304942,
#        32.40965919,  4.99210167, 33.22879138, 26.92633691, 17.18121009,
#        35.190057  , 20.93816067, 26.12023304, 21.73448056, 19.88088848,
#        20.11854341, 18.30689805, 17.57536177, 16.51055755, 19.90924917,
#        18.98273111, 13.09418961, 25.88274974, 25.83898694, 20.48237304,
#        22.70161199, 21.14118241, 24.87001366, 23.99832826, 20.33825082,
#        21.81919535, 21.30366109, 25.41652377, 24.08534478, 16.10131893,
#        18.20910516, 19.17509599, 21.04341295, 25.59905663, 18.1828271 ,
#         2.15597721, 19.88551595, 37.57371139, 11.53877357, 21.39239876,
#        12.489316  , 18.2028807 , 22.18925118, 20.14777524, 29.86805227,
#        26.50387373, 36.46488015, 19.06478154, 20.97782852, 27.16716121,
#        17.72616892, 17.8419814 , 28.88648827, 17.8799802 , 19.85865675,
#        32.12834045, 18.90022081, 28.43852326, 20.98604069, 16.60430702,
# ...

# %%
ytest
# Out:
# 314    23.8
# 421    14.2
# 248    24.5
# 99     33.2
# 264    36.5
#        ...
# 200    32.9
# 51     20.5
# 202    42.3
# 362    20.8
# 398     5.0
# Name: medv, Length: 152, dtype: float64

# %%
comp=pd.DataFrame({'y':ytest,'yhat':yh})
comp
# Out:
#         y       yhat
# 314  23.8  26.048523
# 421  14.2  19.356807
# 248  24.5  25.242685
# 99   33.2  32.115770
# 264  36.5  29.913049
# ..    ...        ...
# 200  32.9  31.800425
# 51   20.5  23.734447
# 202  42.3  34.956714
# 362  20.8  19.566805
# 398   5.0   7.514671
#
# [152 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2=r2_score(ytest,yh)
r2
# Out:
# 0.66954809072139

# %% [markdown]
# # ####################################################
